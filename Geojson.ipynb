# %%
import pandas as pd
import json
import geopandas as gpd
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %%
# !ls
# Out:
# Untitled.ipynb                regions.geojson
# claimsdf_1.csv                regions_2015.prj
# departements.geojson          regions_2015.shp
# france-geojson-master         regions_2015.shx
# georef-france-region?.geojson

# %%
df = pd.read_csv("claimsdf_1.csv")

# %%
df.head()
# Out:
#    ClaimNb  Exposure  Area  BonusMalus  VehBrand  Density  Region  \
# 0        1      0.10     4          50         9     1217      18
# 1        1      0.77     4          50         9     1217      18
# 2        1      0.75     2          50         9       54       3
# 3        1      0.09     2          50         9       76      15
# 4        1      0.84     2          50         9       76      15
#
#    empirical_freq  VehGas_Regular  VehPower_  VehAge_  DrivAge_
# 0       10.000000               1          5        1         6
# 1        1.298701               1          5        1         6
# 2        1.333333               0          6        2         6
# 3       11.111111               0          7        1         5
# 4        1.190476               0          7        1         5

# %%
len(df.Region.unique())
# Out:
# 22

# %% [markdown]
# ### Departamentos

# %%
geo_json = r'departements.geojson'

#open and load the geojson file
with open (geo_json) as geo_file:
    geo_francia =  json.load(geo_file)

# %%
geo_francia.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
for i in range(len(geo_francia.get("features"))):
    print(i)
    print(geo_francia.get("features")[i].get("properties"))
# Out:
# 0
# {'code': '01', 'nom': 'Ain'}
# 1
# {'code': '02', 'nom': 'Aisne'}
# 2
# {'code': '03', 'nom': 'Allier'}
# 3
# {'code': '04', 'nom': 'Alpes-de-Haute-Provence'}
# 4
# {'code': '05', 'nom': 'Hautes-Alpes'}
# 5
# {'code': '06', 'nom': 'Alpes-Maritimes'}
# 6
# {'code': '2A', 'nom': 'Corse-du-Sud'}
# 7
# {'code': '2B', 'nom': 'Haute-Corse'}
# 8
# {'code': '07', 'nom': 'Ardèche'}
# 9
# {'code': '08', 'nom': 'Ardennes'}
# 10
# {'code': '09', 'nom': 'Ariège'}
# 11
# {'code': '10', 'nom': 'Aube'}
# 12
# {'code': '11', 'nom': 'Aude'}
# 13
# {'code': '12', 'nom': 'Aveyron'}
# 14
# {'code': '13', 'nom': 'Bouches-du-Rhône'}
# 15
# {'code': '14', 'nom': 'Calvados'}
# 16
# {'code': '15', 'nom': 'Cantal'}
# 17
# {'code': '16', 'nom': 'Charente'}
# 18
# {'code': '17', 'nom': 'Charente-Maritime'}
# 19
# {'code': '18', 'nom': 'Cher'}
# 20
# {'code': '19', 'nom': 'Corrèze'}
# 21
# {'code': '21', 'nom': "Côte-d'Or"}
# 22
# {'code': '22', 'nom': "Côtes-d'Armor"}
# 23
# {'code': '23', 'nom': 'Creuse'}
# ...

# %%
len(geo_francia.get("features"))
# Out:
# 96

# %% [markdown]
# ### Regiones

# %%
geo_json = r'regions.geojson'

#open and load the geojson file
with open (geo_json) as geo_file:
    geo_francia_regions =  json.load(geo_file)

# %%
geo_francia_regions.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
geo_francia_regions.get("features")
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[2.59052, 49.07965],
#      [2.59602, 49.08171],
#      [2.59787, 49.08179],
#      [2.59993, 49.08408],
#      [2.6033, 49.08588],
#      [2.60818, 49.09013],
#      [2.61033, 49.09305],
#      [2.61034, 49.09494],
#      [2.6169, 49.09389],
#      [2.61834, 49.09474],
#      [2.623, 49.09559],
#      [2.62488, 49.09877],
#      [2.62433, 49.10036],
#      [2.62763, 49.10147],
#      [2.62729, 49.10223],
#      [2.63064, 49.10245],
#      [2.63175, 49.10492],
#      [2.63175, 49.10627],
#      [2.63327, 49.10838],
#      [2.63655, 49.10711],
#      [2.63511, 49.10455],
#      [2.63647, 49.1036],
#      [2.63584, 49.10181],
#      [2.64071, 49.10103],
#      [2.64124, 49.09909],
#      [2.64343, 49.09926],
#      [2.64597, 49.10015],
#      [2.65021, 49.10055],
#      [2.65636, 49.09851],
#      [2.65903, 49.09617],
#      [2.66129, 49.09674],
#      [2.66277, 49.09369],
#      [2.66572, 49.09304],
# ...

# %%
geo_francia_regions.get("features")[0].keys()
# Out:
# dict_keys(['type', 'geometry', 'properties'])

# %%
geo_francia_regions.get("features")[0].get("properties")
# Out:
# {'code': '11', 'nom': 'Île-de-France'}

# %%
for i in range(len(geo_francia_regions.get("features"))):
    print(i)
    print(geo_francia_regions.get("features")[i].get("properties"))
# Out:
# 0
# {'code': '11', 'nom': 'Île-de-France'}
# 1
# {'code': '24', 'nom': 'Centre-Val de Loire'}
# 2
# {'code': '27', 'nom': 'Bourgogne-Franche-Comté'}
# 3
# {'code': '28', 'nom': 'Normandie'}
# 4
# {'code': '32', 'nom': 'Hauts-de-France'}
# 5
# {'code': '44', 'nom': 'Grand Est'}
# 6
# {'code': '52', 'nom': 'Pays de la Loire'}
# 7
# {'code': '53', 'nom': 'Bretagne'}
# 8
# {'code': '75', 'nom': 'Nouvelle-Aquitaine'}
# 9
# {'code': '76', 'nom': 'Occitanie'}
# 10
# {'code': '84', 'nom': 'Auvergne-Rhône-Alpes'}
# 11
# {'code': '93', 'nom': "Provence-Alpes-Côte d'Azur"}
# 12
# {'code': '94', 'nom': 'Corse'}

# %%
geo_francia_regions
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[2.59052, 49.07965],
#       [2.59602, 49.08171],
#       [2.59787, 49.08179],
#       [2.59993, 49.08408],
#       [2.6033, 49.08588],
#       [2.60818, 49.09013],
#       [2.61033, 49.09305],
#       [2.61034, 49.09494],
#       [2.6169, 49.09389],
#       [2.61834, 49.09474],
#       [2.623, 49.09559],
#       [2.62488, 49.09877],
#       [2.62433, 49.10036],
#       [2.62763, 49.10147],
#       [2.62729, 49.10223],
#       [2.63064, 49.10245],
#       [2.63175, 49.10492],
#       [2.63175, 49.10627],
#       [2.63327, 49.10838],
#       [2.63655, 49.10711],
#       [2.63511, 49.10455],
#       [2.63647, 49.1036],
#       [2.63584, 49.10181],
#       [2.64071, 49.10103],
#       [2.64124, 49.09909],
#       [2.64343, 49.09926],
#       [2.64597, 49.10015],
#       [2.65021, 49.10055],
#       [2.65636, 49.09851],
#       [2.65903, 49.09617],
# ...

# %% [markdown]
# ### Regiones II

# %%
# !ls
# Out:
# Untitled.ipynb                regions.geojson
# claimsdf_1.csv                regions_2015.prj
# departements.geojson          regions_2015.shp
# france-geojson-master         regions_2015.shx
# georef-france-region?.geojson

# %%
geo_json = r'georef-france-region?.geojson'

#open and load the geojson file
with open (geo_json) as geo_file:
    geo_francia_regionsII =  json.load(geo_file)

# %%
import fiona

# %%
len(geo_francia_regionsII.get("features")[0].get("properties"))
# Out:
# 11
